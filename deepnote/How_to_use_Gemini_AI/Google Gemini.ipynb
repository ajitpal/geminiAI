# %% [markdown]
# # Setting up

# %% [markdown]
# Get the API key from here: https://ai.google.dev/tutorials/setup

# %%
import google.generativeai as genai
import os
from IPython.display import Markdown, display

gemini_api_key = os.environ["GEMINI_API_KEY"]
genai.configure(api_key = gemini_api_key)


model = genai.GenerativeModel('gemini-pro')

# %% [markdown]
# # Using Gemini Pro

# %%
response = model.generate_content("Who is the God of Universe?")
display(Markdown(response.text))
# Out:
# The concept of the God of the universe varies greatly among different religions, cultures, and spiritual beliefs. Here are some examples of deities or divine beings who are considered the creator and ruler of the universe in various religions and mythologies:
#
# 1. **Abrahamic Religions:**
#    - **Judaism:** In Judaism, God is known as Yahweh or YHWH, the one and only creator of the universe and the God of the Israelites.
#    - **Christianity:** Christians believe in the triune God, consisting of the Father (God the Father), the Son (Jesus Christ), and the Holy Spirit. God is seen as the creator and ruler of the universe, as well as a loving and merciful deity.
#    - **Islam:** Muslims believe in Allah, the one and only God who is all-powerful, all-knowing, and all-merciful. Allah is seen as the creator and sustainer of the universe and the guide for humanity.
#
# 2. **Hinduism:**
#    - **Brahman:** In Hinduism, Brahman is the ultimate reality, the eternal and unchanging principle that underlies all existence. Brahman is often described as being beyond human comprehension and is often associated with the concept of unity and divinity.
#    - **Trimurti:** The Trimurti is a trinity of three deities: Brahma, Vishnu, and Shiva. Brahma is the creator of the universe, Vishnu is the preserver, and Shiva is the destroyer.
#
# 3. **Buddhism:**
#    - **Buddha:** In Buddhism, Buddha (Siddhartha Gautama) is not considered a god but rather an enlightened teacher who achieved liberation from the cycle of rebirth and suffering. However, some Mahayana Buddhist traditions do venerate certain Buddhas, such as Amitabha, as saviors or celestial beings.
#
# 4. **Ancient Egyptian Religion:**
#    - **Amun-Ra:** Amun-Ra was the sun god and king of the gods in ancient Egyptian mythology. He was seen as the creator of the universe and was associated with life, light, and fertility.
#
# 5. **Ancient Greek Religion:**
#    - **Zeus:** Zeus was the king of the gods and goddesses in ancient Greek mythology. He was the god of the sky and thunder and was seen as the ruler of Mount Olympus and the divine order.
#
# 6. **Norse Mythology:**
#    - **Odin:** Odin was the chief god in Norse mythology and was associated with wisdom, war, and death. He was seen as the creator of the world and the leader of the Aesir gods.
#
# 7. **Chinese Mythology:**
#    - **Yu Huang:** Yu Huang, also known as the Jade Emperor, is the supreme ruler of the heavens in Chinese mythology. He is often seen as the creator and ruler of the universe and is worshipped as a deity.
#
# It's important to note that these are just a few examples, and there are many other deities and divine beings worshipped in various cultures and religions worldwide. The concept of the God of the universe is often multifaceted and complex, and it varies depending on one's beliefs and spiritual practices.

# %%
response.candidates
# Out:
# [content {
#   parts {
#     text: "The concept of the God of the universe varies greatly among different religions, cultures, and spiritual beliefs. Here are some examples of deities or divine beings who are considered the creator and ruler of the universe in various religions and mythologies:\n\n1. **Abrahamic Religions:**\n   - **Judaism:** In Judaism, God is known as Yahweh or YHWH, the one and only creator of the universe and the God of the Israelites.\n   - **Christianity:** Christians believe in the triune God, consisting of the Father (God the Father), the Son (Jesus Christ), and the Holy Spirit. God is seen as the creator and ruler of the universe, as well as a loving and merciful deity.\n   - **Islam:** Muslims believe in Allah, the one and only God who is all-powerful, all-knowing, and all-merciful. Allah is seen as the creator and sustainer of the universe and the guide for humanity.\n\n2. **Hinduism:**\n   - **Brahman:** In Hinduism, Brahman is the ultimate reality, the eternal and unchanging principle that underlies all existence. Brahman is often described as being beyond human comprehension and is often associated with the concept of unity and divinity.\n   - **Trimurti:** The Trimurti is a trinity of three deities: Brahma, Vishnu, and Shiva. Brahma is the creator of the universe, Vishnu is the preserver, and Shiva is the destroyer.\n\n3. **Buddhism:**\n   - **Buddha:** In Buddhism, Buddha (Siddhartha Gautama) is not considered a god but rather an enlightened teacher who achieved liberation from the cycle of rebirth and suffering. However, some Mahayana Buddhist traditions do venerate certain Buddhas, such as Amitabha, as saviors or celestial beings.\n\n4. **Ancient Egyptian Religion:**\n   - **Amun-Ra:** Amun-Ra was the sun god and king of the gods in ancient Egyptian mythology. He was seen as the creator of the universe and was associated with life, light, and fertility.\n\n5. **Ancient Greek Religion:**\n   - **Zeus:** Zeus was the king of the gods and goddesses in ancient Greek mythology. He was the god of the sky and thunder and was seen as the ruler of Mount Olympus and the divine order.\n\n6. **Norse Mythology:**\n   - **Odin:** Odin was the chief god in Norse mythology and was associated with wisdom, war, and death. He was seen as the creator of the world and the leader of the Aesir gods.\n\n7. **Chinese Mythology:**\n   - **Yu Huang:** Yu Huang, also known as the Jade Emperor, is the supreme ruler of the heavens in Chinese mythology. He is often seen as the creator and ruler of the universe and is worshipped as a deity.\n\nIt\'s important to note that these are just a few examples, and there are many other deities and divine beings worshipped in various cultures and religions worldwide. The concept of the God of the universe is often multifaceted and complex, and it varies depending on one\'s beliefs and spiritual practices."
#   }
#   role: "model"
# }
# finish_reason: STOP
# index: 0
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }
# ]

# %% [markdown]
# # Code Generation using Gemini Pro

# %%
response = model.generate_content("Build a simple game in Javascript which could be run in browser when the script code run in console.")
display(Markdown(response.text))
# Out:
# ```javascript
# // Define the game state
# let playerScore = 0;
# let computerScore = 0;
# let gameOver = false;
#
# // Define the game logic
# function playRound(playerChoice, computerChoice) {
#   // Convert playerChoice and computerChoice to lowercase for easy comparison
#   playerChoice = playerChoice.toLowerCase();
#   computerChoice = computerChoice.toLowerCase();
#
#   // Check for a tie
#   if (playerChoice === computerChoice) {
#     return "Tie!";
#   }
#
#   // Check for a win or loss
#   if (
#     (playerChoice === "rock" && computerChoice === "scissors") ||
#     (playerChoice === "paper" && computerChoice === "rock") ||
#     (playerChoice === "scissors" && computerChoice === "paper")
#   ) {
#     playerScore++;
#     return "You win!";
#   } else {
#     computerScore++;
#     return "You lose!";
#   }
# }
#
# // Define the game loop
# function gameLoop() {
#   // Check if the game is over
#   if (playerScore === 5 || computerScore === 5) {
#     gameOver = true;
#     return gameOver;
#   }
#
#   // Get the player's choice
#   let playerChoice = prompt("Enter your choice (rock, paper, or scissors): ");
#
#   // Generate the computer's choice
#   let computerChoice = Math.random();
#   if (computerChoice < 0.33) {
#     computerChoice = "rock";
#   } else if (computerChoice < 0.66) {
#     computerChoice = "paper";
#   } else {
#     computerChoice = "scissors";
#   }
#
#   // Play a round of the game
#   let result = playRound(playerChoice, computerChoice);
#
#   // Display the results
#   console.log(`You chose ${playerChoice}.`);
#   console.log(`Computer chose ${computerChoice}.`);
#   console.log(result);
#   console.log(`Your score: ${playerScore}`);
#   console.log(`Computer's score: ${computerScore}`);
#
#   // Continue the game loop
#   if (!gameOver) {
#     gameLoop();
#   } else {
#     if (playerScore > computerScore) {
#       console.log("Congratulations! You won the game.");
#     } else {
#       console.log("Sorry, you lost the game.");
#     }
#   }
# }
#
# // Start the game
# gameLoop();
# ```

# %% [markdown]
# # Content generation using Gemini Pro

# %%
response = model.generate_content(
    'Write a short story about first encounter with outer space.',
    generation_config=genai.types.GenerationConfig(
        candidate_count=1,
        stop_sequences=['space'],
        max_output_tokens=200,
        temperature=0.7)
)

Markdown(response.text)
# Out:
# In the heart of the Mojave Desert, a team of astronomers from the Desert Sky Observatory were deep into a stargazing session, their eyes glued to the telescopes, searching for celestial wonders. Among them was a young astronomer named Anya, whose passion for

# %% [markdown]
# # Streaming Response

# %%
model = genai.GenerativeModel('gemini-pro')
response = model.generate_content("Write a PySpark function for cleaning the data.", stream=True)

for chunk in response:
    print(chunk.text)
# Out:
# ```python
# def clean_data(data):
#   """
#   C
# leans the data by removing duplicate rows,
#   converting date columns to datetime objects,
#   and handling missing values.
#
#   Args:
#     data:
#  A PySpark DataFrame.
#
#   Returns:
#     A PySpark DataFrame with the cleaned data.
#   """
#
#   # Remove duplicate rows
#   data = data.dropDuplicates()
#
#   # Convert date columns to datetime objects
#   for col in data.select_dtypes(include=['date']).columns:
#
#     data[col] = data[col].astype('datetime64')
#
#   # Handle missing values
#   data = data.fillna(data.mean())
#
#   return data
# ```

# %% [markdown]
# # Using Gemini Pro Vision (For Identifying Images metadata)

# %%
import PIL.Image
from IPython.display import display

img = PIL.Image.open('images/taj.jpg')

# Reduce the size of the image before displaying
img.thumbnail((800, 800))

display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x800>

# %%
model = genai.GenerativeModel('gemini-pro-vision')
response = model.generate_content(img)
Markdown(response.text)
# Out:
#  The Taj Mahal is a white marble mausoleum located in Agra, India. It was built by Mughal emperor Shah Jahan and considered to be one of the most beautiful buildings in the world and is a UNESCO World Heritage Site.

# %%
response = model.generate_content(["Write a travel blog post using the image as reference.", img])

Markdown(response.text)
# Out:
#  **The Taj Mahal: A Wonder of the World**
#
# The Taj Mahal is an ivory-white marble mausoleum located in Agra, India. It was built by Mughal emperor Shah Jahan and considered to be one of the most beautiful buildings in the world and is a UNESCO World Heritage Site.
#
# The Taj Mahal was built in memory of Shah Jahan's third wife, Mumtaz Mahal, who died in childbirth in 1631. Construction of the Taj Mahal began in 1632 and was completed in 1653, with an estimated cost of over 32 million rupees.
#
# The Taj Mahal is a large, white marble building with four minarets. The main dome is 58 meters high and is surrounded by four smaller domes. The interior of the Taj Mahal is decorated with intricate carvings and paintings.
#
# The Taj Mahal is a popular tourist destination and is visited by millions of people each year. It is a symbol of love and is a reminder of the beauty that can be created when people work together.
#
# **Here are some tips for visiting the Taj Mahal:**
#
# * Book your tickets in advance, especially if you are visiting during peak season.
# * Arrive early to avoid the crowds.
# * Wear comfortable shoes, as you will be doing a lot of walking.
# * Bring a camera to capture the beauty of the Taj Mahal.
# * Be respectful of the Taj Mahal and its surroundings.
# * The Taj Mahal is a beautiful and awe-inspiring place that is definitely worth a visit. If you are ever in India, be sure to make the time to see this wonder of the world.

# %% [markdown]
# # Chat Conversations Session

# %%
model = genai.GenerativeModel('gemini-pro')

chat = model.start_chat(history=[])

chat.send_message("Can you please guide me on how to start playing Dota 2?")

chat.history
# Out:
# [parts {
#    text: "Can you please guide me on how to start playing Dota 2?"
#  }
#  role: "user",
#  parts {
#    text: "1. **Downloading and Installing Dota 2:**\n   - Visit the official Dota 2 website and create an account.\n   - Download the game client for your platform.\n   - Run the installer and follow the instructions.\n\n2. **Learning the Basics:**\n   - Start by playing the tutorial to learn the basic mechanics of the game.\n   - Read the in-game guides and watch video tutorials for more detailed information.\n   - Practice with bots to get comfortable with the controls and gameplay.\n\n3. **Understanding the Game Modes:**\n   - Dota 2 offers several game modes, including Single Draft, All Random Deathmatch, and the classic 5v5 match.\n   - Different game modes have different rules and objectives, so learn about each one before trying it out.\n\n4. **Choosing a Hero:**\n   - Dota 2 has a wide range of heroes, each with unique abilities and playstyles.\n   - Choose a hero that suits your preferred playstyle and practice with them until you master their skills.\n\n5. **Playing Your Role:**\n   - Dota 2 heroes are classified into different roles, such as carry, support, offlaner, and midlaner.\n   - Each role has a specific function in the team, so learn about the roles and play according to your role.\n\n6. **Participating in Team Fights:**\n   - Team fights are crucial in Dota 2, as they can determine the outcome of a match.\n   - Coordinate with your teammates and use your abilities effectively to win team fights.\n\n7. **Pushing and Destroying Towers:**\n   - One of the objectives in Dota 2 is to push and destroy enemy towers.\n   - Killing enemy heroes and pushing lanes can help you advance towards enemy towers and ultimately destroy them.\n\n8. **Upgrading Your Items:**\n   - Collect gold by killing creeps, heroes, and neutral creeps to upgrade your items.\n   - Items provide various bonuses and abilities, so choose the items that best suit your hero and playstyle.\n\n9. **Communicating with Your Team:*\n   - Effective communication is essential for success in Dota 2.\n   - Use the in-game chat and voice chat to communicate with your teammates, share information, and coordinate strategies.\n\n10. **Working as a Team:**\n   - Remember that Dota 2 is a team game. Cooperate with your teammates, help each other, and adapt your strategies according to the situation."
#  }
#  role: "model"]

# %%
for message in chat.history:
    display(Markdown(f'**{message.role}**: {message.parts[0].text}'))
# Out:
# **user**: Can you please guide me on how to start playing Dota 2?
# **model**: 1. **Downloading and Installing Dota 2:**
#    - Visit the official Dota 2 website and create an account.
#    - Download the game client for your platform.
#    - Run the installer and follow the instructions.
#
# 2. **Learning the Basics:**
#    - Start by playing the tutorial to learn the basic mechanics of the game.
#    - Read the in-game guides and watch video tutorials for more detailed information.
#    - Practice with bots to get comfortable with the controls and gameplay.
#
# 3. **Understanding the Game Modes:**
#    - Dota 2 offers several game modes, including Single Draft, All Random Deathmatch, and the classic 5v5 match.
#    - Different game modes have different rules and objectives, so learn about each one before trying it out.
#
# 4. **Choosing a Hero:**
#    - Dota 2 has a wide range of heroes, each with unique abilities and playstyles.
#    - Choose a hero that suits your preferred playstyle and practice with them until you master their skills.
#
# 5. **Playing Your Role:**
#    - Dota 2 heroes are classified into different roles, such as carry, support, offlaner, and midlaner.
#    - Each role has a specific function in the team, so learn about the roles and play according to your role.
#
# 6. **Participating in Team Fights:**
#    - Team fights are crucial in Dota 2, as they can determine the outcome of a match.
#    - Coordinate with your teammates and use your abilities effectively to win team fights.
#
# 7. **Pushing and Destroying Towers:**
#    - One of the objectives in Dota 2 is to push and destroy enemy towers.
#    - Killing enemy heroes and pushing lanes can help you advance towards enemy towers and ultimately destroy them.
#
# 8. **Upgrading Your Items:**
#    - Collect gold by killing creeps, heroes, and neutral creeps to upgrade your items.
#    - Items provide various bonuses and abilities, so choose the items that best suit your hero and playstyle.
#
# 9. **Communicating with Your Team:*
#    - Effective communication is essential for success in Dota 2.
#    - Use the in-game chat and voice chat to communicate with your teammates, share information, and coordinate strategies.
#
# 10. **Working as a Team:**
#    - Remember that Dota 2 is a team game. Cooperate with your teammates, help each other, and adapt your strategies according to the situation.

# %%
chat.send_message("Which Dota 2 heroes should I start with?")

for message in chat.history:
    display(Markdown(f'**{message.role}**: {message.parts[0].text}'))
# Out:
# **user**: Can you please guide me on how to start playing Dota 2?
# **model**: 1. **Downloading and Installing Dota 2:**
#    - Visit the official Dota 2 website and create an account.
#    - Download the game client for your platform.
#    - Run the installer and follow the instructions.
#
# 2. **Learning the Basics:**
#    - Start by playing the tutorial to learn the basic mechanics of the game.
#    - Read the in-game guides and watch video tutorials for more detailed information.
#    - Practice with bots to get comfortable with the controls and gameplay.
#
# 3. **Understanding the Game Modes:**
#    - Dota 2 offers several game modes, including Single Draft, All Random Deathmatch, and the classic 5v5 match.
#    - Different game modes have different rules and objectives, so learn about each one before trying it out.
#
# 4. **Choosing a Hero:**
#    - Dota 2 has a wide range of heroes, each with unique abilities and playstyles.
#    - Choose a hero that suits your preferred playstyle and practice with them until you master their skills.
#
# 5. **Playing Your Role:**
#    - Dota 2 heroes are classified into different roles, such as carry, support, offlaner, and midlaner.
#    - Each role has a specific function in the team, so learn about the roles and play according to your role.
#
# 6. **Participating in Team Fights:**
#    - Team fights are crucial in Dota 2, as they can determine the outcome of a match.
#    - Coordinate with your teammates and use your abilities effectively to win team fights.
#
# 7. **Pushing and Destroying Towers:**
#    - One of the objectives in Dota 2 is to push and destroy enemy towers.
#    - Killing enemy heroes and pushing lanes can help you advance towards enemy towers and ultimately destroy them.
#
# 8. **Upgrading Your Items:**
#    - Collect gold by killing creeps, heroes, and neutral creeps to upgrade your items.
#    - Items provide various bonuses and abilities, so choose the items that best suit your hero and playstyle.
#
# 9. **Communicating with Your Team:*
#    - Effective communication is essential for success in Dota 2.
#    - Use the in-game chat and voice chat to communicate with your teammates, share information, and coordinate strategies.
#
# 10. **Working as a Team:**
#    - Remember that Dota 2 is a team game. Cooperate with your teammates, help each other, and adapt your strategies according to the situation.
# **user**: Which Dota 2 heroes should I start with?
# **model**: Here are some Dota 2 heroes that are generally considered beginner-friendly and suitable for new players:
#
# **1. Wraith King:**
#    - Wraith King is a durable hero with a straightforward kit. His ultimate ability, Reincarnation, allows him to revive after being killed, making him difficult to take down.
#
# **2. Crystal Maiden:**
#    - Crystal Maiden is a support hero with powerful crowd control and healing abilities. Her ultimate, Freezing Field, slows enemies and deals damage over time, making it a great tool for team fights.
#
# **3. Ogre Magi:**
#    - Ogre Magi is a tanky support hero with simple abilities. His ultimate, Multicast, has a chance to cast his other abilities twice, providing extra damage, crowd control, and healing.
#
# **4. Sven:**
#    - Sven is a carry hero known for his high damage output. His ultimate, Storm Hammer, deals massive damage to a single target, making him a formidable force in team fights.
#
# **5. Luna:**
#    - Luna is an agility carry hero with strong late-game potential. Her ultimate, Eclipse, grants her bonus damage and attack speed, allowing her to deal devastating damage to enemies.
#
# **6. Drow Ranger:**
#    - Drow Ranger is a ranged agility carry hero with long-range attacks. Her ultimate, Marksmanship, increases her attack range and damage, making her a powerful threat from a distance.
#
# **7. Lich:**
#    - Lich is a support hero with crowd control and damage-over-time abilities. His ultimate, Chain Frost, bounces between enemy units, dealing damage and slowing them, making it great for initiating team fights or defending towers.
#
# **8. Zeus:**
#    - Zeus is an intelligence hero with powerful nuking abilities. His ultimate, Thundergod's Wrath, deals massive damage to all enemy units in a large area, making him a deadly force in team fights.
#
# **9. Sniper:**
#    - Sniper is a ranged agility carry hero known for his long-range attacks and high attack speed. His ultimate, Assassinate, allows him to target and kill an enemy unit from across the map, making him a dangerous threat to squishy heroes.
#
# **10.斧王:**
#    - 斧王 is a strength hero with powerful crowd control and initiation abilities. His ultimate, Call, summons a group of Axe's berserkers to attack enemy units, dealing damage and stunning them, making him a great choice for starting team fights.
#
# Remember, these are just a few examples, and there are many other heroes that can be beginner-friendly depending on your playstyle and preferences. Experiment with different heroes to find the ones that you enjoy playing the most.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3162c052-ac05-4477-99fb-33b63286ef04' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
